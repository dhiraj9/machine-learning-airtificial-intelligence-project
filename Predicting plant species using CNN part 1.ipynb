# %%
# !unzip /content/drive/MyDrive/Dataset-Plant-seedlings-classification.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: test/ad12382d4.png
#   inflating: test/adb7a032c.png
#   inflating: test/ae90f2827.png
#   inflating: test/aecfaed64.png
#   inflating: test/aee6fa3df.png
#   inflating: test/af45e222a.png
#   inflating: test/afa446484.png
#   inflating: test/afcf6abd5.png
#   inflating: test/b026bf8ca.png
#   inflating: test/b03397525.png
#   inflating: test/b0acaff4a.png
#   inflating: test/b130a0632.png
#   inflating: test/b145ba9d4.png
#   inflating: test/b1cd2a91e.png
#   inflating: test/b215531dd.png
#   inflating: test/b2706e2b3.png
#   inflating: test/b29339405.png
#   inflating: test/b30ab4659.png
#   inflating: test/b31292706.png
#   inflating: test/b341d0aab.png
#   inflating: test/b39c71707.png
#   inflating: test/b3d6fdb80.png
#   inflating: test/b3e08b037.png
#   inflating: test/b47691c08.png
#   inflating: test/b4c3df835.png
#   inflating: test/b4f7c9214.png
#   inflating: test/b573b7a56.png
# ...

# %%
import cv2
i=cv2.imread('/content/train/Black-grass/0050f38b3.png')
i.shape
# Out:
# (196, 196, 3)

# %%
import matplotlib.pyplot as p
p.imshow(i)

# %%
import cv2
import os
x=[]
y=[]
X=[]
import numpy as n
for i in os.listdir('/content/train/Black-grass'):
    a=cv2.imread('/content/train/Black-grass/'+i)
    a=cv2.resize(a,(224,224))
    X.append(a)
    a=n.reshape(a,(224*224*3))
    x.append(a)
    y.append(1)
for i in os.listdir('/content/train/Charlock'):
    a=cv2.imread('/content/train/Charlock/'+i)
    a=cv2.resize(a,(224,224))
    X.append(a)
    a=n.reshape(a,(224*224*3))
    x.append(a)
    y.append(2)
for i in os.listdir('/content/train/Cleavers'):
    a=cv2.imread('/content/train/Cleavers/'+i)
    a=cv2.resize(a,(224,224))
    X.append(a)
    a=n.reshape(a,(224*224*3))
    x.append(a)
    y.append(3)
for i in os.listdir('/content/train/Common-Chickweed'):
    a=cv2.imread('/content/train/Common-Chickweed/'+i)
    a=cv2.resize(a,(224,224))
    X.append(a)
    a=n.reshape(a,(224*224*3))
    x.append(a)
    y.append(4)
for i in os.listdir('/content/train/Common-wheat'):
    a=cv2.imread('/content/train/Common-wheat/'+i)
    a=cv2.resize(a,(224,224))
    X.append(a)
    a=n.reshape(a,(224*224*3))
    x.append(a)
    y.append(5)
for i in os.listdir('/content/train/Fat-Hen'):
    a=cv2.imread('/content/train/Fat-Hen/'+i)
    a=cv2.resize(a,(224,224))
    X.append(a)
    a=n.reshape(a,(224*224*3))
    x.append(a)
    y.append(6)
for i in os.listdir('/content/train/Loose-Silky-bent'):
    a=cv2.imread('/content/train/Loose-Silky-bent/'+i)
    a=cv2.resize(a,(224,224))
    X.append(a)
    a=n.reshape(a,(224*224*3))
    x.append(a)
    y.append(7)
for i in os.listdir('/content/train/Maize'):
    a=cv2.imread('/content/train/Maize/'+i)
    a=cv2.resize(a,(224,224))
    X.append(a)
    a=n.reshape(a,(224*224*3))
    x.append(a)
    y.append(8)
for i in os.listdir('/content/train/Scentless-Mayweed'):
    a=cv2.imread('/content/train/Scentless-Mayweed/'+i)
    a=cv2.resize(a,(224,224))
    X.append(a)
    a=n.reshape(a,(224*224*3))
    x.append(a)
    y.append(9)
for i in os.listdir('/content/train/Shepherds-Purse'):
    a=cv2.imread('/content/train/Shepherds-Purse/'+i)
    a=cv2.resize(a,(224,224))
    X.append(a)
    a=n.reshape(a,(224*224*3))
    x.append(a)
    y.append(10)
for i in os.listdir('/content/train/Small-flowered-Cranesbill'):
    a=cv2.imread('/content/train/Small-flowered-Cranesbill/'+i)
    a=cv2.resize(a,(224,224))
    X.append(a)
    a=n.reshape(a,(224*224*3))
    x.append(a)
    y.append(11)
for i in os.listdir('/content/train/Sugar-beet'):
    a=cv2.imread('/content/train/Sugar-beet/'+i)
    a=cv2.resize(a,(224,224))
    X.append(a)
    a=n.reshape(a,(224*224*3))
    x.append(a)
    y.append(12)
from sklearn.model_selection import train_test_split

# %%
xt,xte,yt,yte=train_test_split(n.asarray(x),n.asarray(y))
xt=xt.astype('float32')
xt/=255.0
xte=xte.astype('float32')
xte/=255.0
from sklearn.linear_model import LogisticRegression
m=LogisticRegression()
m.fit(xt,yt)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
m.score(xte,yte)
# Out:
# 0.47053872053872053

# %%
import tensorflow as tf
class a(tf.keras.callbacks.Callback):
  def __init__(self,t):
    super(a,self).__init__()
    self.t=t
  def on_epoch_end(self,epoch,logs=None):
    v=logs['val_accuracy']
    if v>=self.t:
      self.model.stop_training=True

# %%
from sklearn.model_selection import train_test_split
xt,xte,yt,yte=train_test_split(n.asarray(X),n.asarray(y))
xt=xt.astype('float32')
xt/=255.0
xte=xte.astype('float32')
xte/=255.0
from tensorflow.keras.utils import to_categorical
ytc=to_categorical(yt)
ytec=to_categorical(yte)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten,Dense,Conv2D,MaxPooling2D,BatchNormalization,Dropout
m=Sequential([Flatten(),Dense(2048,activation='relu'),Dropout(.05),Dense(1024,activation='relu'),Dropout(.05),Dense(512,activation='relu'),Dropout(.05),Dense(256,activation='relu'),Dropout(.05),Dense(128,activation='relu'),Dropout(.05),Dense(12,activation='softmax')])
m.compile(optimizer='adam',loss='categorical_crossentropy',metrics='accuracy')
m=a(t=0.47053872053872053)
m.fit(xt,ytc,validation_data=(xte,ytec),epochs=100,batch_size=128,callbacks=[my_callback])
# Out:
# Epoch 1/100
# ...
# 28/28 [==============================] - 7s 128ms/step - loss: 21.4415 - accuracy: 0.0918 - val_loss: 2.6332 - val_accuracy: 0.1204
# Epoch 2/100
# 28/28 [==============================] - 3s 120ms/step - loss: 2.6410 - accuracy: 0.1075 - val_loss: 2.4693 - val_accuracy: 0.0976
# Epoch 3/100
# 28/28 [==============================] - 3s 122ms/step - loss: 2.4951 - accuracy: 0.1058 - val_loss: 2.4577 - val_accuracy: 0.1347
# Epoch 4/100
# 28/28 [==============================] - 3s 121ms/step - loss: 2.4704 - accuracy: 0.1109 - val_loss: 2.4214 - val_accuracy: 0.1406
# Epoch 5/100
# 28/28 [==============================] - 3s 121ms/step - loss: 2.4505 - accuracy: 0.1213 - val_loss: 2.4523 - val_accuracy: 0.0690
# Epoch 6/100
# 28/28 [==============================] - 3s 123ms/step - loss: 2.4555 - accuracy: 0.1277 - val_loss: 2.4263 - val_accuracy: 0.1406
# Epoch 7/100
# ...

# %%
m=Sequential([Conv2D(64,(3,3),activation='relu',input_shape=X[0].shape[0:]),MaxPooling2D(2,2),Conv2D(32,(3,3),activation='relu'),Conv2D(16,(3,3),activation='relu'),Flatten(),Dense(512,activation='relu'),Dense(12,activation='softmax')])
m.compile(optimizer='adam',loss='categorical_crossentropy',metrics='accuracy')
m.fit(xt,ytc,validation_data=(xte,ytec),epochs=10,batch_size=256)
# Out:
# Epoch 1/10
# 14/14 [==============================] - 47s 883ms/step - loss: 3.5407 - accuracy: 0.1289 - val_loss: 2.4150 - val_accuracy: 0.1448
# Epoch 2/10
# 14/14 [==============================] - 7s 519ms/step - loss: 2.3682 - accuracy: 0.1850 - val_loss: 2.4877 - val_accuracy: 0.1532
# Epoch 3/10
# 14/14 [==============================] - 7s 513ms/step - loss: 2.1738 - accuracy: 0.2785 - val_loss: 2.0101 - val_accuracy: 0.3258
# Epoch 4/10
# 14/14 [==============================] - 7s 519ms/step - loss: 1.7529 - accuracy: 0.4045 - val_loss: 1.6966 - val_accuracy: 0.3973
# Epoch 5/10
# 14/14 [==============================] - 7s 526ms/step - loss: 1.4674 - accuracy: 0.4913 - val_loss: 1.5445 - val_accuracy: 0.4604
# Epoch 6/10
# 14/14 [==============================] - 7s 529ms/step - loss: 1.2240 - accuracy: 0.6075 - val_loss: 1.6282 - val_accuracy: 0.4394
# Epoch 7/10
# ...

# %% [markdown]
# CNN out performs neural networks which in turn out perform supervised learning model. Both cnn & neural networks suffer from overfitting as training accuracy is greater than valiadation accuracy

# %%
m.save('m.h5')

# %%
i=cv2.imread('/content/test/00c47e980.png')
import matplotlib.pyplot as p
p.imshow(i)

# %%
from keras.preprocessing import image
a=image.load_img('/content/test/00c47e980.png',target_size=(224,224))
b=image.img_to_array(a)
import numpy as np
b=np.expand_dims(b,axis=0)
b/=255.
m.predict(b)
# Out:
# array([[0.26915967, 0.00200635, 0.00351533, 0.00125218, 0.54307973,
#         0.02365951, 0.11452603, 0.0019762 , 0.01602932, 0.00069403,
#         0.00619266, 0.01790903]], dtype=float32)

# %% [markdown]
# CNN out performs neural networks which in turn out perform supervised learning models when it comes to image classification as neural networks & supervised learning models as cnn filters extract edges of images which determine the image whereas neural networks & supervised learning models consider all pixels as features which is not as good a technique as cnn as image data will have lot of pixels
