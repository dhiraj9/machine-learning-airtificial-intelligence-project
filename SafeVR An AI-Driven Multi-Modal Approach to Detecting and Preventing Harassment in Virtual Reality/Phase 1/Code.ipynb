# %%
# !pip install --upgrade google-api-python-client
from googleapiclient.discovery import build
import pprint

api_key = "AIzaSyAz5d7JnNXnsP-QF6Y71oxeX6s8bvZ2wYo"

youtube = build('youtube', 'v3', developerKey=api_key)

# Define the search terms
search_terms = query_terms = [
    "VRchat Privacy Risk",
    "Altspace VR and Harassment Danger",
    "Horizon Worlds: Metaverse Safety Issues",
    "Virtual Reality and the Risk of Poor Conduct",
    "Toxic Behavior in VRChat",
    "Privacy Concerns in Social VR",
    "Metaverse and the Harm of Cyberbullying",
    "Safety Measures in Rec Room VR",
    "Altspace VR: Navigating Virtual Harassment",
    "Horizon Worlds and the Risk of Cyberstalking",
    "VR and the Danger of Invasion of Privacy",
    "VRchat: A Breeding Ground for Toxicity?",
    "Metaverse Safety: Understanding the Risks",
    "Virtual Reality Illness: A Concern for Rec Room Users",
    "Social VR Platforms and their Harassment Issues",
    "VR Hatred: The Dark Side of Altspace VR",
    "The Safety of Children in Metaverse",
    "Managing Risk in Horizon Worlds",
    "Dangers of Inappropriate Conduct in Virtual Reality",
    "Coping with the Toxicity in VRchat",
    "Privacy Invasion: The Hidden Danger in Social VR",
    "Virtual Harassment: The Unseen Risk in Horizon Worlds",
    "Cyberbullying in the Metaverse: A Growing Concern",
    "Rec Room and the Potential for Virtual Harm",
    "Altspace VR and the Issue of Cyberstalking",
    "The Risk of Sick Behavior in Virtual Reality",
    "Safety Risks in the VR Metaverse",
    "Handling Poor Conduct in Horizon Worlds",
    "The Potential for Harassment in VRChat",
    "Social VR: Navigating the Dangers of the Metaverse",
    "Cyber Threats: The Dark Side of Altspace VR",
    "Virtual Reality and the Risk of Online Bullying in Rec Room",
    "Horizon Worlds and the Danger of Privacy Infringement",
    "Dealing with the Risk of Toxicity in VRChat",
    "Virtual Reality and its Potential for Harm",
    "Metaverse: Navigating the Threats of Social VR",
    "Safety Precautions in Horizon Worlds",
    "Altspace VR: Confronting the Danger of Cyber Harassment",
    "Privacy Issues: A Growing Concern in Social VR",
    "Virtual Reality Sickness: A Hidden Risk in VRChat",
    "Rec Room and the Perils of Cyberbullying",
    "The Danger of Poor Conduct in the Metaverse",
    "Threats to Safety in Altspace VR",
    "Cyberstalking: A Rising Issue in Horizon Worlds",
    "The Harm of Hate Speech in Social VR",
    "VRChat: Battling the Issues of Online Harassment",
    "Virtual Reality: The Risk of Encountering Toxic Behavior",
    "Personal Safety in the Metaverse: Risks and Challenges",
    "Rec Room: Navigating the Danger of Virtual Harassment",
    "Altspace VR and the Threat of Privacy Breach",
    "Toxicity in the Metaverse: A Concern for All",
    "Horizon Worlds and the Problem of Cyberbullying",
    "VRChat: The Risk of Invasion of Privacy",
    "The Potential for Unwanted Behavior in Social VR",
    "Cyber Harassment: The Unsaid Risk of Virtual Reality",
    "Metaverse: The Threat of Virtual Harassment",
    "Privacy Breaches in Horizon Worlds: An Urgent Issue",
    "Managing Toxic Behavior in Altspace VR",
    "Dealing with Cyber Threats in VRChat",
    "Social VR: Understanding the Dangers of Online Bullying",
    "Cyber Threats in the Metaverse: Navigating the Risks",
    "VRChat and the Dangers of Cyberbullying",
    "Metaverse Privacy Risks: Are We Safe in Horizon Worlds?",
    "Social VR: Understanding the Risks of Virtual Harassment",
    "Toxicity in Rec Room: A Growing Safety Concern",
    "Navigating the Threat of Cyberstalking in Altspace VR",
    "The Issue of Inappropriate Conduct in Virtual Reality",
    "Privacy Invasion in VRChat: A Silent Risk",
    "Metaverse and the Problem of Online Harassment",
    "VR Sickness: The Unseen Danger in Horizon Worlds",
    "Threats to Personal Safety in Social VR Platforms",
    "The Risk of Harmful Behavior in Altspace VR",
    "VRChat: Battling the Threat of Cyberbullying",
    "Hate Speech in Rec Room: A Safety Issue",
    "The Risk of Cyber Harassment in the Metaverse",
    "Toxicity in Horizon Worlds: A Growing Concern",
    "Altspace VR: Navigating Privacy Risks",
    "Potential Risks of Inappropriate Conduct in VRChat",
    "Social VR: The Dangers of Cyberstalking",
    "Privacy Breaches in Horizon Worlds: An Ongoing Issue",
    "Dealing with the Risk of Online Harassment in Rec Room",
    "Harmful Conduct in Altspace VR: A Safety Risk",
    "VRChat and the Danger of Cyber Threats",
    "The Issue of Virtual Harassment in the Metaverse",
    "Rec Room and the Challenge of Toxicity",
    "The Problem of Online Bullying in Horizon Worlds",
    "Cyber Harassment in Social VR: A Growing Concern",
    "Threats to Personal Privacy in VRChat",
    "Virtual Reality: Understanding the Dangers of Cyberstalking",
    "The Risk of Inappropriate Conduct in Altspace VR",
    "Rec Room: Managing the Threat of Cyberbullying",
    "Privacy Risks in Horizon Worlds: Navigating the Metaverse",
    "Social VR and the Danger of Harmful Conduct",
    "The Problem of Toxicity in VRChat",
    "The Issue of Online Harassment in Virtual Reality",
    "Cyberbullying in Rec Room: A Safety Concern",
    "Navigating the Risk of Privacy Invasion in Altspace VR",
    "The Challenge of Toxic Behavior in Horizon Worlds",
    "VRChat: Dealing with the Risk of Cyber Harassment",
    "Virtual Reality: Understanding the Danger of Cyber Threats",
    "The Issue of Inappropriate Conduct in Social VR Platforms"]



# Define how many results you want (max is 50 per request due to API limits)
max_results = 50

# Open the file to write the URLs
with open("urls.txt", "w") as f:
    # Loop over each search term
    for search_term in search_terms:

        # Create request
        request = youtube.search().list(
            part="snippet",
            q=search_term,
            maxResults=max_results,
            type="video" # to search for videos only
        )

        # Execute the request
        response = request.execute()

        # Write each URL to the file
        for item in response['items']:
            url = "https://www.youtube.com/watch?v=" + item['id']['videoId']
            f.write(url + "\n")
