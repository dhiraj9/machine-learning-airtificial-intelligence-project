# %%
import cv2
import matplotlib.pyplot as p
import os
y=1
for i in range(1,10):
    p.figure(figsize=(2,2))
    p.imshow(cv2.imread('New folder (5)/0000'+str(i)+'.jpg'))
    p.title(y)
    y+=1
p.show()

# %%
for i in range(10,16):
    p.figure(figsize=(2,2))
    p.imshow(cv2.imread('New folder (5)/000'+str(i)+'.jpg'))
    p.title(y)
    y+=1
p.show()

# %% [markdown]
# challenges faced during this task are the images are of different sizes,in a single images there are multiple cars,backgrounds are different,car name not properly visible,there is unwanted text in images
